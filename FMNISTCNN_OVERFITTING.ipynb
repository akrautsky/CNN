# %%
#import tensorflow
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step
# 68616192/68606236 [==============================] - 0s 0us/step

# %%
print("Path for the downloaded folder {}".format(zip_dir))
print('base directory {} '.format(os.path.join(os.path.dirname(zip_dir))))
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats') 
train_dogs_dir = os.path.join(train_dir, 'dogs') 
validation_cats_dir = os.path.join(validation_dir, 'cats') 
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
# Out:
# Path for the downloaded folder /root/.keras/datasets/cats_and_dogs_filterted.zip
# base directory /root/.keras/datasets

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %%
BATCH_SIZE = 100  # Number of training examples to process before updating our models variables
IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %%
train_image_generator      = ImageDataGenerator(rescale=1./255)  # Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255)  # Generator for our validation data

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_data_gen)

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:5])

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 20/20 [==============================] - 22s 538ms/step - loss: 0.7446 - accuracy: 0.5050 - val_loss: 0.6849 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.6872 - accuracy: 0.5500 - val_loss: 0.6708 - val_accuracy: 0.6340
# Epoch 3/100
# 20/20 [==============================] - 10s 525ms/step - loss: 0.6567 - accuracy: 0.5925 - val_loss: 0.6524 - val_accuracy: 0.6070
# Epoch 4/100
# 20/20 [==============================] - 10s 525ms/step - loss: 0.6420 - accuracy: 0.6140 - val_loss: 0.6252 - val_accuracy: 0.6690
# Epoch 5/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.6034 - accuracy: 0.6605 - val_loss: 0.5858 - val_accuracy: 0.6820
# Epoch 6/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.5464 - accuracy: 0.7170 - val_loss: 0.5934 - val_accuracy: 0.6750
# Epoch 7/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.4896 - accuracy: 0.7610 - val_loss: 0.5592 - val_accuracy: 0.7260
# Epoch 8/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.4584 - accuracy: 0.7890 - val_loss: 0.5520 - val_accuracy: 0.7090
# Epoch 9/100
# 20/20 [==============================] - 10s 521ms/step - loss: 0.4420 - accuracy: 0.7915 - val_loss: 0.5683 - val_accuracy: 0.6910
# Epoch 10/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.4278 - accuracy: 0.7970 - val_loss: 0.5596 - val_accuracy: 0.7240
# Epoch 11/100
# 20/20 [==============================] - 10s 525ms/step - loss: 0.3544 - accuracy: 0.8380 - val_loss: 0.5457 - val_accuracy: 0.7290
# Epoch 12/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.3116 - accuracy: 0.8580 - val_loss: 0.5693 - val_accuracy: 0.7290
# Epoch 13/100
# 20/20 [==============================] - 10s 520ms/step - loss: 0.2776 - accuracy: 0.8785 - val_loss: 0.6316 - val_accuracy: 0.7380
# Epoch 14/100
# 20/20 [==============================] - 10s 525ms/step - loss: 0.2475 - accuracy: 0.8940 - val_loss: 0.6455 - val_accuracy: 0.7530
# Epoch 15/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.1796 - accuracy: 0.9250 - val_loss: 0.6567 - val_accuracy: 0.7620
# Epoch 16/100
# 20/20 [==============================] - 10s 525ms/step - loss: 0.1425 - accuracy: 0.9465 - val_loss: 0.7891 - val_accuracy: 0.7450
# Epoch 17/100
# 20/20 [==============================] - 10s 523ms/step - loss: 0.1135 - accuracy: 0.9590 - val_loss: 0.7629 - val_accuracy: 0.7490
# Epoch 18/100
# 20/20 [==============================] - 10s 519ms/step - loss: 0.0701 - accuracy: 0.9815 - val_loss: 0.8763 - val_accuracy: 0.7570
# Epoch 19/100
# 20/20 [==============================] - 10s 519ms/step - loss: 0.0402 - accuracy: 0.9920 - val_loss: 0.9518 - val_accuracy: 0.7660
# Epoch 20/100
# 20/20 [==============================] - 10s 519ms/step - loss: 0.0399 - accuracy: 0.9900 - val_loss: 1.1480 - val_accuracy: 0.7510
# Epoch 21/100
# 20/20 [==============================] - 10s 517ms/step - loss: 0.0484 - accuracy: 0.9810 - val_loss: 1.0396 - val_accuracy: 0.7520
# Epoch 22/100
# 20/20 [==============================] - 10s 519ms/step - loss: 0.0538 - accuracy: 0.9815 - val_loss: 1.0614 - val_accuracy: 0.7220
# Epoch 23/100
# 20/20 [==============================] - 10s 520ms/step - loss: 0.0717 - accuracy: 0.9705 - val_loss: 1.1107 - val_accuracy: 0.7340
# Epoch 24/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.0428 - accuracy: 0.9855 - val_loss: 1.2604 - val_accuracy: 0.7280
# Epoch 25/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.0406 - accuracy: 0.9890 - val_loss: 1.0571 - val_accuracy: 0.7550
# Epoch 26/100
# 20/20 [==============================] - 10s 518ms/step - loss: 0.0155 - accuracy: 0.9980 - val_loss: 1.2184 - val_accuracy: 0.7470
# Epoch 27/100
# 20/20 [==============================] - 10s 520ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 1.4310 - val_accuracy: 0.7440
# Epoch 28/100
# 20/20 [==============================] - 10s 521ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.4669 - val_accuracy: 0.7490
# Epoch 29/100
# 20/20 [==============================] - 10s 517ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.5017 - val_accuracy: 0.7480
# Epoch 30/100
# 20/20 [==============================] - 10s 519ms/step - loss: 7.9761e-04 - accuracy: 1.0000 - val_loss: 1.5572 - val_accuracy: 0.7560
# Epoch 31/100
# 20/20 [==============================] - 10s 522ms/step - loss: 4.8369e-04 - accuracy: 1.0000 - val_loss: 1.5901 - val_accuracy: 0.7500
# Epoch 32/100
# 20/20 [==============================] - 10s 516ms/step - loss: 3.8981e-04 - accuracy: 1.0000 - val_loss: 1.6043 - val_accuracy: 0.7530
# Epoch 33/100
# 20/20 [==============================] - 10s 518ms/step - loss: 3.2563e-04 - accuracy: 1.0000 - val_loss: 1.6226 - val_accuracy: 0.7480
# Epoch 34/100
# 20/20 [==============================] - 10s 516ms/step - loss: 2.8826e-04 - accuracy: 1.0000 - val_loss: 1.6354 - val_accuracy: 0.7520
# Epoch 35/100
# 20/20 [==============================] - 10s 519ms/step - loss: 2.5617e-04 - accuracy: 1.0000 - val_loss: 1.6516 - val_accuracy: 0.7510
# Epoch 36/100
# 20/20 [==============================] - 10s 521ms/step - loss: 2.2891e-04 - accuracy: 1.0000 - val_loss: 1.6655 - val_accuracy: 0.7500
# Epoch 37/100
# 20/20 [==============================] - 10s 524ms/step - loss: 2.0893e-04 - accuracy: 1.0000 - val_loss: 1.6796 - val_accuracy: 0.7530
# Epoch 38/100
# 20/20 [==============================] - 10s 522ms/step - loss: 1.9262e-04 - accuracy: 1.0000 - val_loss: 1.6921 - val_accuracy: 0.7530
# Epoch 39/100
# 20/20 [==============================] - 10s 524ms/step - loss: 1.7613e-04 - accuracy: 1.0000 - val_loss: 1.7030 - val_accuracy: 0.7550
# Epoch 40/100
# 20/20 [==============================] - 10s 520ms/step - loss: 1.6308e-04 - accuracy: 1.0000 - val_loss: 1.7145 - val_accuracy: 0.7530
# Epoch 41/100
# 20/20 [==============================] - 10s 521ms/step - loss: 1.5183e-04 - accuracy: 1.0000 - val_loss: 1.7260 - val_accuracy: 0.7530
# Epoch 42/100
# 20/20 [==============================] - 10s 521ms/step - loss: 1.4181e-04 - accuracy: 1.0000 - val_loss: 1.7366 - val_accuracy: 0.7520
# Epoch 43/100
# 20/20 [==============================] - 10s 514ms/step - loss: 1.3274e-04 - accuracy: 1.0000 - val_loss: 1.7452 - val_accuracy: 0.7530
# Epoch 44/100
# 20/20 [==============================] - 10s 520ms/step - loss: 1.2484e-04 - accuracy: 1.0000 - val_loss: 1.7551 - val_accuracy: 0.7540
# Epoch 45/100
# 20/20 [==============================] - 10s 519ms/step - loss: 1.1685e-04 - accuracy: 1.0000 - val_loss: 1.7648 - val_accuracy: 0.7540
# Epoch 46/100
# 20/20 [==============================] - 10s 522ms/step - loss: 1.1052e-04 - accuracy: 1.0000 - val_loss: 1.7741 - val_accuracy: 0.7540
# Epoch 47/100
# 20/20 [==============================] - 10s 523ms/step - loss: 1.0384e-04 - accuracy: 1.0000 - val_loss: 1.7820 - val_accuracy: 0.7560
# Epoch 48/100
# 20/20 [==============================] - 10s 524ms/step - loss: 9.9146e-05 - accuracy: 1.0000 - val_loss: 1.7902 - val_accuracy: 0.7540
# Epoch 49/100
# 20/20 [==============================] - 10s 523ms/step - loss: 9.3906e-05 - accuracy: 1.0000 - val_loss: 1.7986 - val_accuracy: 0.7540
# Epoch 50/100
# 20/20 [==============================] - 10s 519ms/step - loss: 8.8864e-05 - accuracy: 1.0000 - val_loss: 1.8058 - val_accuracy: 0.7550
# Epoch 51/100
# 20/20 [==============================] - 10s 520ms/step - loss: 8.4641e-05 - accuracy: 1.0000 - val_loss: 1.8135 - val_accuracy: 0.7550
# Epoch 52/100
# 20/20 [==============================] - 10s 516ms/step - loss: 8.0722e-05 - accuracy: 1.0000 - val_loss: 1.8213 - val_accuracy: 0.7550
# Epoch 53/100
# 20/20 [==============================] - 10s 518ms/step - loss: 7.6996e-05 - accuracy: 1.0000 - val_loss: 1.8293 - val_accuracy: 0.7560
# Epoch 54/100
# 20/20 [==============================] - 10s 516ms/step - loss: 7.3370e-05 - accuracy: 1.0000 - val_loss: 1.8358 - val_accuracy: 0.7560
# Epoch 55/100
# 20/20 [==============================] - 10s 518ms/step - loss: 7.0248e-05 - accuracy: 1.0000 - val_loss: 1.8428 - val_accuracy: 0.7550
# Epoch 56/100
# 20/20 [==============================] - 10s 520ms/step - loss: 6.7533e-05 - accuracy: 1.0000 - val_loss: 1.8494 - val_accuracy: 0.7560
# Epoch 57/100
# 20/20 [==============================] - 10s 516ms/step - loss: 6.4451e-05 - accuracy: 1.0000 - val_loss: 1.8561 - val_accuracy: 0.7560
# Epoch 58/100
# 20/20 [==============================] - 10s 516ms/step - loss: 6.2087e-05 - accuracy: 1.0000 - val_loss: 1.8621 - val_accuracy: 0.7560
# Epoch 59/100
# 20/20 [==============================] - 10s 514ms/step - loss: 5.9584e-05 - accuracy: 1.0000 - val_loss: 1.8679 - val_accuracy: 0.7560
# Epoch 60/100
# 20/20 [==============================] - 10s 513ms/step - loss: 5.7113e-05 - accuracy: 1.0000 - val_loss: 1.8748 - val_accuracy: 0.7550
# Epoch 61/100
# 20/20 [==============================] - 10s 516ms/step - loss: 5.4959e-05 - accuracy: 1.0000 - val_loss: 1.8810 - val_accuracy: 0.7560
# Epoch 62/100
# 20/20 [==============================] - 10s 517ms/step - loss: 5.2941e-05 - accuracy: 1.0000 - val_loss: 1.8862 - val_accuracy: 0.7570
# Epoch 63/100
# 20/20 [==============================] - 10s 518ms/step - loss: 5.1029e-05 - accuracy: 1.0000 - val_loss: 1.8922 - val_accuracy: 0.7570
# Epoch 64/100
# 20/20 [==============================] - 10s 515ms/step - loss: 4.9208e-05 - accuracy: 1.0000 - val_loss: 1.8985 - val_accuracy: 0.7560
# Epoch 65/100
# 20/20 [==============================] - 10s 514ms/step - loss: 4.7472e-05 - accuracy: 1.0000 - val_loss: 1.9038 - val_accuracy: 0.7570
# Epoch 66/100
# 20/20 [==============================] - 10s 515ms/step - loss: 4.5718e-05 - accuracy: 1.0000 - val_loss: 1.9087 - val_accuracy: 0.7570
# Epoch 67/100
# 20/20 [==============================] - 10s 520ms/step - loss: 4.4259e-05 - accuracy: 1.0000 - val_loss: 1.9150 - val_accuracy: 0.7570
# Epoch 68/100
# 20/20 [==============================] - 10s 517ms/step - loss: 4.2759e-05 - accuracy: 1.0000 - val_loss: 1.9196 - val_accuracy: 0.7570
# Epoch 69/100
# 20/20 [==============================] - 10s 521ms/step - loss: 4.1245e-05 - accuracy: 1.0000 - val_loss: 1.9254 - val_accuracy: 0.7560
# Epoch 70/100
# 20/20 [==============================] - 10s 516ms/step - loss: 3.9956e-05 - accuracy: 1.0000 - val_loss: 1.9309 - val_accuracy: 0.7570
# Epoch 71/100
# 20/20 [==============================] - 10s 513ms/step - loss: 3.8645e-05 - accuracy: 1.0000 - val_loss: 1.9353 - val_accuracy: 0.7570
# Epoch 72/100
# 20/20 [==============================] - 10s 517ms/step - loss: 3.7466e-05 - accuracy: 1.0000 - val_loss: 1.9402 - val_accuracy: 0.7570
# Epoch 73/100
# 20/20 [==============================] - 10s 516ms/step - loss: 3.6336e-05 - accuracy: 1.0000 - val_loss: 1.9454 - val_accuracy: 0.7570
# Epoch 74/100
# 20/20 [==============================] - 10s 519ms/step - loss: 3.5346e-05 - accuracy: 1.0000 - val_loss: 1.9504 - val_accuracy: 0.7570
# Epoch 75/100
# 20/20 [==============================] - 10s 514ms/step - loss: 3.4100e-05 - accuracy: 1.0000 - val_loss: 1.9549 - val_accuracy: 0.7580
# Epoch 76/100
# 20/20 [==============================] - 10s 516ms/step - loss: 3.3109e-05 - accuracy: 1.0000 - val_loss: 1.9597 - val_accuracy: 0.7580
# Epoch 77/100
# 20/20 [==============================] - 10s 517ms/step - loss: 3.2160e-05 - accuracy: 1.0000 - val_loss: 1.9647 - val_accuracy: 0.7570
# Epoch 78/100
# 20/20 [==============================] - 10s 515ms/step - loss: 3.1213e-05 - accuracy: 1.0000 - val_loss: 1.9698 - val_accuracy: 0.7580
# Epoch 79/100
# 20/20 [==============================] - 10s 514ms/step - loss: 3.0352e-05 - accuracy: 1.0000 - val_loss: 1.9740 - val_accuracy: 0.7580
# Epoch 80/100
# 20/20 [==============================] - 10s 517ms/step - loss: 2.9451e-05 - accuracy: 1.0000 - val_loss: 1.9783 - val_accuracy: 0.7570
# Epoch 81/100
# 20/20 [==============================] - 10s 519ms/step - loss: 2.8735e-05 - accuracy: 1.0000 - val_loss: 1.9825 - val_accuracy: 0.7580
# Epoch 82/100
# 20/20 [==============================] - 10s 517ms/step - loss: 2.7968e-05 - accuracy: 1.0000 - val_loss: 1.9870 - val_accuracy: 0.7580
# Epoch 83/100
# 20/20 [==============================] - 10s 519ms/step - loss: 2.7237e-05 - accuracy: 1.0000 - val_loss: 1.9915 - val_accuracy: 0.7580
# Epoch 84/100
# 20/20 [==============================] - 10s 515ms/step - loss: 2.6460e-05 - accuracy: 1.0000 - val_loss: 1.9964 - val_accuracy: 0.7580
# Epoch 85/100
# 20/20 [==============================] - 10s 516ms/step - loss: 2.5706e-05 - accuracy: 1.0000 - val_loss: 2.0000 - val_accuracy: 0.7580
# Epoch 86/100
# 20/20 [==============================] - 10s 515ms/step - loss: 2.5003e-05 - accuracy: 1.0000 - val_loss: 2.0047 - val_accuracy: 0.7580
# Epoch 87/100
# 20/20 [==============================] - 10s 515ms/step - loss: 2.4406e-05 - accuracy: 1.0000 - val_loss: 2.0087 - val_accuracy: 0.7580
# Epoch 88/100
# 20/20 [==============================] - 10s 514ms/step - loss: 2.3786e-05 - accuracy: 1.0000 - val_loss: 2.0130 - val_accuracy: 0.7580
# Epoch 89/100
# 20/20 [==============================] - 10s 516ms/step - loss: 2.3207e-05 - accuracy: 1.0000 - val_loss: 2.0173 - val_accuracy: 0.7580
# Epoch 90/100
# 20/20 [==============================] - 10s 514ms/step - loss: 2.2595e-05 - accuracy: 1.0000 - val_loss: 2.0214 - val_accuracy: 0.7580
# Epoch 91/100
# 20/20 [==============================] - 10s 514ms/step - loss: 2.2030e-05 - accuracy: 1.0000 - val_loss: 2.0255 - val_accuracy: 0.7580
# Epoch 92/100
# 20/20 [==============================] - 10s 517ms/step - loss: 2.1502e-05 - accuracy: 1.0000 - val_loss: 2.0295 - val_accuracy: 0.7580
# Epoch 93/100
# 20/20 [==============================] - 10s 519ms/step - loss: 2.0970e-05 - accuracy: 1.0000 - val_loss: 2.0331 - val_accuracy: 0.7580
# Epoch 94/100
# 20/20 [==============================] - 10s 518ms/step - loss: 2.0492e-05 - accuracy: 1.0000 - val_loss: 2.0374 - val_accuracy: 0.7570
# Epoch 95/100
# 20/20 [==============================] - 10s 517ms/step - loss: 2.0009e-05 - accuracy: 1.0000 - val_loss: 2.0417 - val_accuracy: 0.7580
# Epoch 96/100
# 20/20 [==============================] - 10s 518ms/step - loss: 1.9529e-05 - accuracy: 1.0000 - val_loss: 2.0448 - val_accuracy: 0.7580
# Epoch 97/100
# 20/20 [==============================] - 10s 519ms/step - loss: 1.9056e-05 - accuracy: 1.0000 - val_loss: 2.0489 - val_accuracy: 0.7580
# Epoch 98/100
# 20/20 [==============================] - 10s 519ms/step - loss: 1.8609e-05 - accuracy: 1.0000 - val_loss: 2.0535 - val_accuracy: 0.7560
# Epoch 99/100
# 20/20 [==============================] - 10s 520ms/step - loss: 1.8160e-05 - accuracy: 1.0000 - val_loss: 2.0569 - val_accuracy: 0.7570
# Epoch 100/100
# 20/20 [==============================] - 10s 519ms/step - loss: 1.7772e-05 - accuracy: 1.0000 - val_loss: 2.0600 - val_accuracy: 0.7540

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
